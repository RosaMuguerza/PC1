# %% [markdown]
# ## Read the data
#
# This code will give you the data you will use for this PC:

# %%
# read web table into pandas DF
import pandas as pd

co2Link='https://docs.google.com/spreadsheets/d/e/2PACX-1vRXjfxeKHQBBCh_oHP-D6RIHEX4eduLjydHb6ZGsU4jo0IK0KKQSoYX_X1FGssC_9hnqCgjKN0K4AVf/pub?gid=775098192&single=true&output=csv'
carbon=pd.read_csv(co2Link)

# %%
# here it is:
carbon
# Out:
#                                               name  metric tonnes of CO2  \
# 0                                            China          1.219600e+10
# 1                                    United States          4.795000e+09
# 2                                            India          2.821000e+09
# 3                                           Russia          1.844000e+09
# 4                                            Japan          9.602300e+08
# ..                                             ...                   ...
# 211              Falkland Islands (Islas Malvinas)          3.600000e+01
# 212                                     Montserrat          2.400000e+01
# 213                                     Antarctica          1.500000e+01
# 214  Saint Helena, Ascension, and Tristan da Cunha          1.200000e+01
# 215                                           Niue          9.000000e+00
#
#      date_of_information  ranking                             region
# ...

# %% [markdown]
# As you see, some columns have space, which should be deleted:

# %%
# also
carbon.columns
# Out:
# Index(['name', 'metric tonnes of CO2', 'date_of_information', 'ranking',
#        'region'],
#       dtype='object')

# %%
# Like this
carbon.rename(columns={'metric tonnes of CO2':'metric_tonnes_of_CO2'},inplace=True)

# see
carbon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  216 non-null    object
#  1   metric_tonnes_of_CO2  216 non-null    float64
#  2   date_of_information   216 non-null    int64
#  3   ranking               216 non-null    int64
#  4   region                216 non-null    object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 8.6+ KB

# %% [markdown]
# You always make a copy:

# %%
carbon_copy=carbon.copy()

# %% [markdown]
# ## Questions

# %% [markdown]
# Complete the tasks requested using **carbon_copy**:
#
# 1. Keep all the columns but _Ranking_:
#     * Tip: use [drop](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html), [loc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html), and [iloc](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html) for the same purpose (three ways to accomplish the task).
#
# 2. Find the country with the minimum CO2 emission in the world.
#
# 3. Find the country with the minimum CO2 emission per Region.
#
# 4. Create a new column by keeping the square root of the the original CO2  column.
#
# 5. Compute the average of CO2. Then, create a new column. This new column is
# the original CO2 minus the average computed.
#
# You have changed **carbon_copy**, now save it as a file like this:

# %%
# carbon_copy.to_csv("carbon_copy.csv",index=False)

# %% [markdown]
# ##SOLUCIÓN

# %% [markdown]
# ## PREGUNTA 1

# %%
# Guardo todas las columnas excepto RANKING
# drop elimina la columna RANKING y "inplace" para sobreescribir en el data carbon_copy
carbon_copy.drop(columns=['ranking'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-1c2f531c7c2a> in <cell line: 0>()
#       1 # Guardo todas las columnas excepto RANKING
#       2 # drop elimina la columna RANKING y "inplace" para sobreescribir en el data carbon_copy
# ----> 3 carbon_copy.drop(columns=['ranking'],inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# ...

# %%
carbon_copy
# Out:
#                                               name  metric_tonnes_of_CO2  \
# 0                                            China          1.219600e+10
# 1                                    United States          4.795000e+09
# 2                                            India          2.821000e+09
# 3                                           Russia          1.844000e+09
# 4                                            Japan          9.602300e+08
# ..                                             ...                   ...
# 211              Falkland Islands (Islas Malvinas)          3.600000e+01
# 212                                     Montserrat          2.400000e+01
# 213                                     Antarctica          1.500000e+01
# 214  Saint Helena, Ascension, and Tristan da Cunha          1.200000e+01
# 215                                           Niue          9.000000e+00
#
#      date_of_information                             region
# ...

# %% [markdown]
# ## PREGUNTA 2

# %%
#Para encontrar el país con menor emisión CO2 utilizamos la función "min" y especifico que solo coloque el nombre
carbon_copy[carbon_copy.metric_tonnes_of_CO2==min(carbon_copy.metric_tonnes_of_CO2)]['name']
# Out:
# 215    Niue
# Name: name, dtype: object

# %% [markdown]
# ## PREGUNTA 3

# %%
#Primero identifico todas las regiones en la lista
carbon_copy['region'].unique()
# Out:
# array(['East and Southeast Asia', 'North America', 'South Asia',
#        'Central Asia', 'Middle East', 'Europe', 'Africa', 'South America',
#        'Australia and Oceania', 'Central America and the Caribbean',
#        'Antarctica'], dtype=object)

# %%
#Creo un data frame para cada región para después encontrar país con menor emisión CO2 POR REGIÓN utilizando la función "min"

c1=carbon_copy[carbon_copy.region=='East and Southeast Asia']
c2=carbon_copy[carbon_copy.region=='North America']
c3=carbon_copy[carbon_copy.region=='South Asia']
c4=carbon_copy[carbon_copy.region=='Central Asia']
c5=carbon_copy[carbon_copy.region=='Middle East']
c6=carbon_copy[carbon_copy.region=='Europe']
c7=carbon_copy[carbon_copy.region=='Africa']
c8=carbon_copy[carbon_copy.region=='South America']
c9=carbon_copy[carbon_copy.region=='Australia and Oceania']
c10=carbon_copy[carbon_copy.region=='Central America and the Caribbean']
c11=carbon_copy[carbon_copy.region=='Antarctica']

# %%
c1[c1.metric_tonnes_of_CO2==c1.metric_tonnes_of_CO2.min()]['name']
# Out:
# 184    Timor-Leste
# Name: name, dtype: object

# %%
c2[c2.metric_tonnes_of_CO2==c2.metric_tonnes_of_CO2.min()]['name']
# Out:
# 210    Saint Pierre and Miquelon
# Name: name, dtype: object

# %%
c3[c3.metric_tonnes_of_CO2==c3.metric_tonnes_of_CO2.min()]['name']
# Out:
# 177    Bhutan
# Name: name, dtype: object

# %%
c4[c4.metric_tonnes_of_CO2==c4.metric_tonnes_of_CO2.min()]['name']
# Out:
# 121    Armenia
# Name: name, dtype: object

# %%
c5[c5.metric_tonnes_of_CO2==c5.metric_tonnes_of_CO2.min()]['name']
# Out:
# 141    Gaza Strip
# 142     West Bank
# Name: name, dtype: object

# %%
c6[c6.metric_tonnes_of_CO2==c6.metric_tonnes_of_CO2.min()]['name']
# Out:
# 175    Faroe Islands
# Name: name, dtype: object

# %%
c7[c7.metric_tonnes_of_CO2==c7.metric_tonnes_of_CO2.min()]['name']
# Out:
# 214    Saint Helena, Ascension, and Tristan da Cunha
# Name: name, dtype: object

# %%
c8[c8.metric_tonnes_of_CO2==c8.metric_tonnes_of_CO2.min()]['name']
# Out:
# 211    Falkland Islands (Islas Malvinas)
# Name: name, dtype: object

# %%
c9[c9.metric_tonnes_of_CO2==c9.metric_tonnes_of_CO2.min()]['name']
# Out:
# 215    Niue
# Name: name, dtype: object

# %%
c10[c10.metric_tonnes_of_CO2==c10.metric_tonnes_of_CO2.min()]['name']
# Out:
# 212    Montserrat
# Name: name, dtype: object

# %%
c11[c11.metric_tonnes_of_CO2==c11.metric_tonnes_of_CO2.min()]['name']
# Out:
# 213    Antarctica
# Name: name, dtype: object

# %% [markdown]
# ## PREGUNTA 4

# %%
#Creo una lista con los valores de raíz cuadrada
square_root=carbon_copy.metric_tonnes_of_CO2.apply(lambda x:x**0.5)

square_root
# Out:
# 0      110435.501538
# 1       69245.938509
# 2       53113.086900
# 3       42941.821107
# 4       30987.578156
#            ...
# 211         6.000000
# 212         4.898979
# 213         3.872983
# 214         3.464102
# 215         3.000000
# Name: metric_tonnes_of_CO2, Length: 216, dtype: float64

# %%
# Y se añade esta lista al data frame carbon_copy
carbon_copy=carbon_copy.assign(square_root_metric_tonnes_of_CO2=square_root)
carbon_copy
# Out:
#                                               name  metric_tonnes_of_CO2  \
# 0                                            China          1.219600e+10
# 1                                    United States          4.795000e+09
# 2                                            India          2.821000e+09
# 3                                           Russia          1.844000e+09
# 4                                            Japan          9.602300e+08
# ..                                             ...                   ...
# 211              Falkland Islands (Islas Malvinas)          3.600000e+01
# 212                                     Montserrat          2.400000e+01
# 213                                     Antarctica          1.500000e+01
# 214  Saint Helena, Ascension, and Tristan da Cunha          1.200000e+01
# 215                                           Niue          9.000000e+00
#
#      date_of_information                             region  \
# ...

# %% [markdown]
# ##PREGUNTA 5

# %%
#Calculo el promedio de CO2
promedio_CO2=carbon_copy['metric_tonnes_of_CO2'].mean()
promedio_CO2
# Out:
# np.float64(171564562.3412037)

# %%
#Añado la columna 'difference' al data frame carbon_copy
carbon_copy['difference']=carbon_copy['metric_tonnes_of_CO2']-promedio_CO2
carbon_copy
# Out:
#                                               name  metric_tonnes_of_CO2  \
# 0                                            China          1.219600e+10
# 1                                    United States          4.795000e+09
# 2                                            India          2.821000e+09
# 3                                           Russia          1.844000e+09
# 4                                            Japan          9.602300e+08
# ..                                             ...                   ...
# 211              Falkland Islands (Islas Malvinas)          3.600000e+01
# 212                                     Montserrat          2.400000e+01
# 213                                     Antarctica          1.500000e+01
# 214  Saint Helena, Ascension, and Tristan da Cunha          1.200000e+01
# 215                                           Niue          9.000000e+00
#
#      date_of_information                             region  \
# ...
